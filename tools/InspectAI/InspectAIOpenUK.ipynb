# %% [markdown]
# ## Inspect

# %%
## retrieve secrets
import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
os.environ["GITHUB_TOKEN"] = userdata.get('GITHUB_TOKEN')
os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')

# %% [markdown]
# ### Start a poetry environment

# %%
# !curl -sSL https://install.python-poetry.org | python3 -
# add to path
import os
os.environ["PATH"] = '/root/.local/bin' + os.pathsep + os.environ["PATH"]
# !which poetry
# Out:
# Retrieving Poetry metadata
#
# # Welcome to Poetry!
#
# This will download and install the latest version of Poetry,
# a dependency and package manager for Python.
#
# It will add the `poetry` command to Poetry's bin directory, located at:
#
# /root/.local/bin
#
# You can uninstall at any time by executing this script with the --uninstall option,
# and these changes will be reverted.
#
# Installing Poetry (2.1.1)
# Installing Poetry (2.1.1): Creating environment
# Installing Poetry (2.1.1): Installing Poetry
# Installing Poetry (2.1.1): Creating script
# Installing Poetry (2.1.1): Done
#
# Poetry (2.1.1) is installed now. Great!
#
# To get started you need Poetry's bin directory (/root/.local/bin) in your `PATH`
# environment variable.
#
# Add `export PATH="/root/.local/bin:$PATH"` to your shell configuration file.
#
# Alternatively, you can call Poetry explicitly with `/root/.local/bin/poetry`.
#
# You can test that everything is set up by executing:
#
# `poetry --version`
#
# ...

# %%
# !git clone https://github.com/albrodfer1/kubecon-ai-days-talk.git
# %cd kubecon-ai-days-talk/notebooks/inspectAIOpenUK
# !poetry config virtualenvs.create false
# !poetry install --no-root
# %cd ../../..
# Out:
# Cloning into 'kubecon-ai-days-talk'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 109 (delta 32), reused 85 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (109/109), 5.34 MiB | 13.87 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/kubecon-ai-days-talk/notebooks/inspectAIOpenUK
# Skipping virtualenv creation, as specified in config file.
# Installing dependencies from lock file
#
# Package operations: 19 installs, 20 updates, 0 removals
#
#   - Downgrading multidict (6.2.0 -> 6.1.0): Pending...
#   - Downgrading propcache (0.3.0 -> 0.2.1): Pending...
#   - Downgrading propcache (0.3.0 -> 0.2.1): Downloading... 0%
#   - Downgrading propcache (0.3.0 -> 0.2.1): Downloading... 0%
#   - Downgrading multidict (6.2.0 -> 6.1.0): Downloading... 0%
#   - Downgrading propcache (0.3.0 -> 0.2.1): Downloading... 0%
# ...

# %%
# !which inspect
# Out:
# /usr/local/bin/inspect

# %% [markdown]
# ### Prepare results persistance
#
# We will mount gdrive to persist the results in our google drive

# %%
# Connect to Google drive to save run results
from google.colab import drive
drive.mount('/content/gdrive')
# !mkdir -p /content/gdrive/MyDrive/runs/inspectAI
# Out:
# Mounted at /content/gdrive

# %%
# perform analysis of gpt-4o
# %cd /content/gdrive/MyDrive/runs/inspectAI
# !inspect eval inspect_evals/agentharm --model openai/gpt-4o-2024-08-06
# Out:
# /content/gdrive/MyDrive/runs/inspectAI
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Fetching 6 files:   0% 0/6 [00:00<?, ?it/s]
# harmful_behaviors_validation.json: 100% 22.6k/22.6k [00:00<00:00, 62.1MB/s]
#
# chat_validation.json: 100% 3.13k/3.13k [00:00<00:00, 14.7MB/s]
#
# harmful_behaviors_test_public.json: 100% 134k/134k [00:00<00:00, 4.13MB/s]
#
# chat_public_test.json: 100% 18.0k/18.0k [00:00<00:00, 43.8MB/s]
#
# benign_behaviors_test_public.json: 100% 139k/139k [00:00<00:00, 1.49MB/s]
# Fetching 6 files:  17% 1/6 [00:01<00:05,  1.15s/it]
# benign_behaviors_validation.json: 100% 23.5k/23.5k [00:00<00:00, 56.6MB/s]
# Fetching 6 files: 100% 6/6 [00:01<00:00,  4.81it/s]
# [>1u[?2026$p[?2048$p
#   Tasks   Running Samples   Console
# ...
