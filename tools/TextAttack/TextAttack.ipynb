# %% [markdown]
# ## TextAttack
#
# TextAttack is a Python framework for adversarial attacks, data augmentation, and model training in NLP.

# %% [markdown]
# ### Poetry
#
# We use poetry for dependency pinning

# %%
# Install Poetry
# !curl -sSL https://install.python-poetry.org | python3 -
import os
os.environ['PATH'] = '/root/.local/bin' + ':' + os.environ['PATH']
# !which poetry
# Out:
# Retrieving Poetry metadata
#
# # Welcome to Poetry!
#
# This will download and install the latest version of Poetry,
# a dependency and package manager for Python.
#
# It will add the `poetry` command to Poetry's bin directory, located at:
#
# /root/.local/bin
#
# You can uninstall at any time by executing this script with the --uninstall option,
# and these changes will be reverted.
#
# Installing Poetry (2.1.1)
# Installing Poetry (2.1.1): Creating environment
# Installing Poetry (2.1.1): Installing Poetry
# Installing Poetry (2.1.1): Creating script
# Installing Poetry (2.1.1): Done
#
# Poetry (2.1.1) is installed now. Great!
#
# To get started you need Poetry's bin directory (/root/.local/bin) in your `PATH`
# environment variable.
#
# Add `export PATH="/root/.local/bin:$PATH"` to your shell configuration file.
#
# Alternatively, you can call Poetry explicitly with `/root/.local/bin/poetry`.
#
# You can test that everything is set up by executing:
#
# `poetry --version`
#
# /root/.local/bin/poetry

# %%
# !mkdir textattack-example
# %cd textattack-example
# !poetry init --no-interaction
# !poetry config virtualenvs.create false
# !poetry add textattack
# %cd ..
# Out:
# /content/textattack-example
# Skipping virtualenv creation, as specified in config file.
# Using version ^0.3.10 for textattack
#
# Updating dependencies
# Resolving dependencies... (60.8s)
#
# Package operations: 34 installs, 22 updates, 0 removals
#
#   - Downgrading nvidia-nvjitlink-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-nvjitlink-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-nvjitlink-cu12 (12.5.82 -> 12.4.127): Downloading... 70%
#   - Downgrading nvidia-nvjitlink-cu12 (12.5.82 -> 12.4.127): Downloading... 100%
#   - Downgrading nvidia-nvjitlink-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-nvjitlink-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8): Pending...
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Pending...
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Pending...
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8): Downloading... 0%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Pending...
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 0%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 10%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 10%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8): Downloading... 10%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 10%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 20%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 30%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 30%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8): Downloading... 20%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 30%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 40%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 50%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 50%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8): Downloading... 30%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 50%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 60%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 70%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 70%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8): Downloading... 40%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 70%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 80%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 80%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8): Downloading... 50%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 80%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 90%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 90%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8): Downloading... 60%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 90%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 90%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8): Downloading... 70%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 90%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 100%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 100%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8): Downloading... 80%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 100%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 100%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8): Downloading... 90%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Downloading... 100%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Installing...
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Installing...
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8): Downloading... 100%
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Installing...
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Installing...
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8): Installing...
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170): Installing...
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170)
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170)
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.4.5.8)
#   - Downgrading nvidia-cusparse-cu12 (12.5.1.3 -> 12.3.1.170)
#   - Downgrading fsspec (2025.3.0 -> 2024.12.0): Pending...
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Pending...
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Pending...
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Pending...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Pending...
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Pending...
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Pending...
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Pending...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Pending...
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Pending...
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Pending...
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Pending...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Pending...
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Pending...
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Pending...
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Pending...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Pending...
#   - Downgrading fsspec (2025.3.0 -> 2024.12.0): Downloading... 0%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Pending...
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Pending...
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Pending...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Pending...
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Pending...
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Pending...
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Pending...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Pending...
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Pending...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Pending...
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Pending...
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Pending...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Pending...
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Pending...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Pending...
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Pending...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Pending...
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Pending...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Pending...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Pending...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Pending...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Pending...
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Pending...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading fsspec (2025.3.0 -> 2024.12.0): Downloading... 100%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading fsspec (2025.3.0 -> 2024.12.0): Installing...
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Downloading... 80%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Downloading... 100%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 10%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 0%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 10%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 10%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 20%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 10%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 10%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 30%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 10%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 10%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 40%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 10%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 20%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 20%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 50%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 20%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 0%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 7%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 20%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 7%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 60%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 20%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 7%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 7%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 30%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 7%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 30%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 7%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 70%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 30%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 7%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 7%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 7%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 30%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 7%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 80%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 30%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 7%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 7%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 40%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 7%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 40%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 90%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 40%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 50%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 50%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 100%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 50%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 100%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 50%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading fsspec (2025.3.0 -> 2024.12.0)
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Downloading... 100%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 50%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 1%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 4%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 7%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 7%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 2%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 7%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 2%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 7%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 60%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 2%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 7%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 2%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 7%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 2%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 7%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 60%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 2%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 7%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 60%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 2%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 7%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 2%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 7%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 70%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 2%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 7%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 10%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 2%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 10%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 80%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 2%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 10%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 10%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 17%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 17%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 40%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 17%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 2%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 10%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 40%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 17%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 90%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 2%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 10%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 40%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 17%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 20%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 10%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 40%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 20%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 4%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 10%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 40%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 20%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 4%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 10%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 40%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 20%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Downloading... 100%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 4%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 10%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 40%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 20%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 50%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 20%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 60%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 20%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 60%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 20%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 16%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 60%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 20%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 30%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 70%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 30%
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 4%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 16%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 70%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 30%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 4%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 16%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 70%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 30%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 70%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 30%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 20%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 70%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 30%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 20%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 70%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 30%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 6%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 20%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 70%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 30%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 80%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 30%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 90%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 30%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 40%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 40%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 100%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 40%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 100%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 40%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 27%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 100%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 40%
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 6%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 27%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 100%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 40%
#   - Downgrading nvidia-cuda-cupti-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cuda-nvrtc-cu12 (12.5.82 -> 12.4.127): Installing...
#   - Downgrading nvidia-cuda-runtime-cu12 (12.5.82 -> 12.4.127)
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 6%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 27%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 100%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 40%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 27%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 100%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 40%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 8%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 27%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 100%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 40%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 100%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 40%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 30%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 100%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 40%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 50%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 30%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 100%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 50%
#   - Downgrading nvidia-cudnn-cu12 (9.3.0.75 -> 9.1.0.70): Downloading... 10%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 30%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Downloading... 100%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 50%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 60%
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 60%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Installing...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 60%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Installing...
#   - Downgrading nvidia-cusolver-cu12 (11.6.3.83 -> 11.6.1.9): Downloading... 60%
#   - Downgrading nvidia-cufft-cu12 (11.2.3.61 -> 11.2.1.3): Downloading... 39%
#   - Downgrading nvidia-curand-cu12 (10.3.6.82 -> 10.3.5.147): Installing...
# ...
#   - Installing lemminflect (0.2.3): Downloading... 0%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Downloading... 60%
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing lemminflect (0.2.3): Downloading... 0%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Downloading... 60%
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 0%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Downloading... 60%
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 0%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Downloading... 60%
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing flair (0.15.1): Downloading... 10%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 0%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Downloading... 60%
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing flair (0.15.1): Downloading... 10%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 0%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Downloading... 60%
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing datasets (3.4.1): Downloading... 30%
#   - Installing flair (0.15.1): Downloading... 10%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 0%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Downloading... 60%
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Downloading... 60%
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing lemminflect (0.2.3): Downloading... 20%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Downloading... 60%
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing num2words (0.5.14): Downloading... 100%
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing num2words (0.5.14): Installing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing flair (0.15.1): Downloading... 10%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 20%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Installing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing datasets (3.4.1): Downloading... 50%
#   - Installing flair (0.15.1): Downloading... 10%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 20%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Installing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Installing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing lemminflect (0.2.3): Downloading... 40%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Installing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 40%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Installing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing flair (0.15.1): Downloading... 30%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 40%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Installing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 0%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing pinyin (0.4.0): Downloading... 10%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing flair (0.15.1): Downloading... 30%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 40%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Installing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 10%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing datasets (3.4.1): Downloading... 100%
#   - Installing flair (0.15.1): Downloading... 30%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 40%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Installing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 10%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing flair (0.15.1): Downloading... 30%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 40%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Installing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 10%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing datasets (3.4.1): Installing...
#   - Installing flair (0.15.1): Downloading... 30%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 40%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Installing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 10%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Installing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 10%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing lemminflect (0.2.3): Downloading... 100%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14): Installing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 10%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 10%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 10%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 100%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 10%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing flair (0.15.1): Downloading... 90%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 100%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 10%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing pinyin (0.4.0): Downloading... 30%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing datasets (3.4.1): Installing...
#   - Installing flair (0.15.1): Downloading... 90%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 100%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 30%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing bert-score (0.3.13)
#   - Installing datasets (3.4.1): Installing...
#   - Installing flair (0.15.1): Downloading... 90%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Downloading... 100%
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 30%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 30%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing lemminflect (0.2.3): Installing...
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 30%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Installing...
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 30%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing flair (0.15.1): Downloading... 100%
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3): Installing...
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 30%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 30%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing lemminflect (0.2.3)
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 30%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3)
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 30%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing flair (0.15.1): Installing...
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3)
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Downloading... 30%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing pinyin (0.4.0): Downloading... 80%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing pinyin (0.4.0): Downloading... 100%
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing pinyin (0.4.0): Preparing...
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing flair (0.15.1): Installing...
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3)
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Preparing...
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing datasets (3.4.1)
#   - Installing flair (0.15.1): Installing...
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3)
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Preparing...
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
# Installing /usr/local/lib/python3.11/dist-packages/tests/__init__.py over existing file
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3)
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Preparing...
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing flair (0.15.1)
#   - Installing language-tool-python (2.9.0)
#   - Installing lemminflect (0.2.3)
#   - Installing lru-dict (1.3.0)
#   - Installing num2words (0.5.14)
#   - Installing openhownet (2.0)
#   - Installing pinyin (0.4.0): Preparing...
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1): Preparing...
#   - Installing word2number (1.1): Installing...
#   - Installing word2number (1.1)
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1)
#   - Installing pinyin (0.4.0): Installing...
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1)
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1)
#   - Installing pinyin (0.4.0)
#   - Installing terminaltables (3.1.10)
#   - Installing word2number (1.1)
#   - Installing textattack (0.3.10): Pending...
#   - Installing textattack (0.3.10): Downloading... 0%
#   - Installing textattack (0.3.10): Downloading... 100%
#   - Installing textattack (0.3.10): Installing...
#   - Installing textattack (0.3.10)
#
# Writing lock file
# /content

# %% [markdown]
# ### Check that the CLI is installed
#
# In this step we will make sure the CLI is installed

# %%
# !which textattack
# Out:
# /usr/local/bin/textattack

# %% [markdown]
# ### Run attack (fails)
#
# we run the following attack: TextFooler against BERT fine-tuned on SST-2

# %%
# !textattack attack --model bert-base-uncased-sst2 --recipe textfooler --num-examples 10
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 2025-03-21 16:31:07.876575: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-21 16:31:07.894826: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742574667.917228    1856 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742574667.924005    1856 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-21 16:31:07.946254: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# README.md: 100% 35.3k/35.3k [00:00<00:00, 51.7MB/s]
# train-00000-of-00001.parquet: 100% 3.11M/3.11M [00:00<00:00, 109MB/s]
# validation-00000-of-00001.parquet: 100% 72.8k/72.8k [00:00<00:00, 209MB/s]
# test-00000-of-00001.parquet: 100% 148k/148k [00:00<00:00, 261MB/s]
# Generating train split: 100% 67349/67349 [00:00<00:00, 1940818.01 examples/s]
# Generating validation split: 100% 872/872 [00:00<00:00, 354230.81 examples/s]
# Generating test split: 100% 1821/1821 [00:00<00:00, 567952.68 examples/s]
# textattack: Loading datasets dataset glue, subset sst2, split validation.
# textattack: Loading pre-trained model from HuggingFace model repository: textattack/bert-base-uncased-SST-2
# config.json: 100% 477/477 [00:00<00:00, 4.20MB/s]
# pytorch_model.bin: 100% 438M/438M [00:02<00:00, 216MB/s]
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 403kB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 1.06MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 638kB/s]
# textattack: Downloading https://textattack.s3.amazonaws.com/word_embeddings/paragramcf.
# 100% 481M/481M [00:48<00:00, 9.83MB/s]
# textattack: Unzipping file /root/.cache/textattack/tmp3l1bkarb.zip to /root/.cache/textattack/word_embeddings/paragramcf.
# textattack: Successfully saved word_embeddings/paragramcf to cache.
# textattack: Unknown if model of class <class 'transformers.models.bert.modeling_bert.BertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  delete
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  WordSwapEmbedding(
#     (max_candidates):  50
#     (embedding):  WordEmbedding
#   )
#   (constraints):
#     (0): WordEmbeddingDistance(
#         (embedding):  WordEmbedding
#         (min_cos_sim):  0.5
#         (cased):  False
#         (include_unknown_words):  True
#         (compare_against_original):  True
#       )
#     (1): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#     (2): UniversalSentenceEncoder(
#         (metric):  angular
#         (threshold):  0.840845057
#         (window_size):  15
#         (skip_text_shorter_than_window):  True
#         (compare_against_original):  False
#       )
#     (3): RepeatModification
#     (4): StopwordModification
#     (5): InputColumnModification(
#         (matching_column_labels):  ['premise', 'hypothesis']
#         (columns_to_ignore):  {'premise'}
#       )
#   (is_black_box):  True
# )
#
#   0% 0/10 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/usr/local/bin/textattack", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/textattack/commands/textattack_cli.py", line 49, in main
#     func.run(args)
#   File "/usr/local/lib/python3.11/dist-packages/textattack/commands/attack_command.py", line 36, in run
#     attacker.attack_dataset()
#   File "/usr/local/lib/python3.11/dist-packages/textattack/attacker.py", line 441, in attack_dataset
#     self._attack()
#   File "/usr/local/lib/python3.11/dist-packages/textattack/attacker.py", line 170, in _attack
#     raise e
#   File "/usr/local/lib/python3.11/dist-packages/textattack/attacker.py", line 168, in _attack
#     result = self.attack.attack(example, ground_truth_output)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/textattack/attack.py", line 450, in attack
#     result = self._attack(goal_function_result)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/textattack/attack.py", line 398, in _attack
#     final_result = self.search_method(initial_result)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/textattack/search_methods/search_method.py", line 35, in __call__
#     result = self.perform_search(initial_result)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/textattack/search_methods/greedy_word_swap_wir.py", line 141, in perform_search
#     transformed_text_candidates = self.get_transformations(
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/textattack/attack.py", line 315, in get_transformations
#     return self.filter_transformations(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/textattack/attack.py", line 380, in filter_transformations
#     filtered_texts += self._filter_transformations_uncached(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/textattack/attack.py", line 340, in _filter_transformations_uncached
#     filtered_texts = C.call_many(filtered_texts, original_text)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/textattack/constraints/constraint.py", line 50, in call_many
#     filtered_texts = self._check_constraint_many(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/textattack/constraints/constraint.py", line 63, in _check_constraint_many
#     return [
#            ^
#   File "/usr/local/lib/python3.11/dist-packages/textattack/constraints/constraint.py", line 66, in <listcomp>
#     if self._check_constraint(transformed_text, reference_text)
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/textattack/constraints/grammaticality/part_of_speech.py", line 132, in _check_constraint
#     ref_pos = self._get_pos(before_ctx, reference_word, after_ctx)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/textattack/constraints/grammaticality/part_of_speech.py", line 90, in _get_pos
#     *nltk.pos_tag(
#      ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nltk/tag/__init__.py", line 168, in pos_tag
#     tagger = _get_tagger(lang)
#              ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nltk/tag/__init__.py", line 110, in _get_tagger
#     tagger = PerceptronTagger()
#              ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nltk/tag/perceptron.py", line 183, in __init__
#     self.load_from_json(lang)
#   File "/usr/local/lib/python3.11/dist-packages/nltk/tag/perceptron.py", line 273, in load_from_json
#     loc = find(f"taggers/averaged_perceptron_tagger_{lang}/")
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nltk/data.py", line 579, in find
#     raise LookupError(resource_not_found)
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger_eng not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger_eng')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger_eng/
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#   0% 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### Run attack v2
#
# we run seq2sick (black-box) against T5 fine-tuned for English-German translation.
#
#
# #### What is seq2sick?
#
# Seq2Sick is an adversarial attack method designed for sequence-to-sequence (seq2seq) models, which are commonly used in tasks like machine translation, text summarization, and speech-to-text. The goal of the Seq2Sick attack is to subtly modify input sequences (adversarial perturbations) to cause the model to produce incorrect or undesired outputs, while keeping the input perturbation minimal and imperceptible.
#
# Key Details of Seq2Sick:
# Focus on Seq2Seq Models:
#
# Seq2Seq models consist of an encoder (to process input) and a decoder (to generate output). Seq2Sick manipulates the input to mislead the decoder.
# Adversarial Objective:
#
# The attack maximizes the divergence between the model's output on the original input and the perturbed input.
# Ensures that the perturbations are small and not easily noticeable (e.g., minor changes to characters or words).
# Optimization-Based Attack:
#
# Seq2Sick uses an optimization process to find minimal perturbations that maximize the model's output error.
# Often implemented using Projected Gradient Descent (PGD) or other adversarial optimization methods.
# Applications:
#
# Target tasks like machine translation, where small changes to the input could result in translations that are semantically incorrect or misleading.
# Demonstrates vulnerabilities in seq2seq systems, highlighting the need for robust defenses.
# Example:
# Imagine using a seq2seq model for machine translation (e.g., English to Spanish). The original input might be:
#
# "I love programming."
#
# The Seq2Sick attack might modify it slightly to:
#
# "I love proggramming."
#
# #### Output explanation

# %%
# !textattack attack --model t5-en-de --recipe seq2sick --num-examples 100
# Out:
# 2025-03-21 16:34:28.997963: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-21 16:34:29.016358: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742574869.038219    2797 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742574869.044989    2797 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-21 16:34:29.067548: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# README.md: 100% 8.14k/8.14k [00:00<00:00, 34.6MB/s]
# ted_multi.py: 100% 5.85k/5.85k [00:00<00:00, 26.3MB/s]
# The repository for ted_multi contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/ted_multi.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# Downloading data: 100% 352M/352M [00:21<00:00, 16.7MB/s]
# Generating train split: 100% 258098/258098 [00:50<00:00, 5099.92 examples/s]
# Generating validation split: 100% 6049/6049 [00:01<00:00, 4791.80 examples/s]
# Generating test split: 100% 7213/7213 [00:01<00:00, 4293.09 examples/s]
# config.json: 100% 1.21k/1.21k [00:00<00:00, 9.49MB/s]
# model.safetensors: 100% 892M/892M [00:03<00:00, 228MB/s]
# generation_config.json: 100% 147/147 [00:00<00:00, 1.24MB/s]
# spiece.model: 100% 792k/792k [00:00<00:00, 3.57MB/s]
# tokenizer.json: 100% 1.39M/1.39M [00:00<00:00, 5.91MB/s]
# textattack: Goal function <class 'textattack.goal_functions.text.non_overlapping_output.NonOverlappingOutput'> compatible with model T5ForTextToText.
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  NonOverlappingOutput
#   (transformation):  WordSwapEmbedding(
#     (max_candidates):  50
#     (embedding):  WordEmbedding
#   )
#   (constraints):
#     (0): LevenshteinEditDistance(
#         (max_edit_distance):  30
#         (compare_against_original):  True
#       )
#     (1): RepeatModification
#     (2): StopwordModification
#   (is_black_box):  True
# )
#
#   0% 0/100 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:676: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
#   1% 1/100 [00:07<11:37,  7.04s/it]--------------------------------------------- Result 1 ---------------------------------------------
# <pad> Bis Ende dieses Jahres wird es</s> --> [FAILED]
#
# By the end of this year , there &apos;ll be nearly a billion people on this planet that actively use social networking sites .
#
#
# [Succeeded / Failed / Skipped / Total] 0 / 1 / 0 / 1:   2% 2/100 [00:08<06:44,  4.13s/it]--------------------------------------------- Result 2 ---------------------------------------------
# <pad> Eines haben sie alle gemeinsam:</s> --> <pad> Eines haben alle gemeinsam: Sie</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# The one thing that all of them have in common is that they &apos;re going to die .
#
# A one thing that all of them have in common is that they &apos;re going to die .
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 1 / 0 / 2:   3% 3/100 [00:17<09:13,  5.70s/it]--------------------------------------------- Result 3 ---------------------------------------------
# <pad> Das mag ein etwas morbider Gedanke sein, aber ich denke,</s> --> [FAILED]
#
# While that might be a somewhat morbid thought , I think it has some really profound implications that are worth exploring .
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 2 / 0 / 3:   4% 4/100 [00:26<10:33,  6.60s/it]--------------------------------------------- Result 4 ---------------------------------------------
# <pad> Was mich zuerst darüber nachgedacht hat, war ein Blog-Post, der --> [FAILED]
#
# What first got me thinking about this was a blog post authored earlier this year by Derek K. Miller , who was a science and technology journalist who died of cancer .
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 3 / 0 / 4:   5% 5/100 [00:33<10:43,  6.77s/it]--------------------------------------------- Result 5 ---------------------------------------------
# <pad> Und was Miller getan hat, war, seine Familie und Freunde einen Beitrag schreiben zu --> [FAILED]
#
# And what Miller did was have his family and friends write a post that went out shortly after he died .
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 4 / 0 / 5:   6% 6/100 [00:34<08:53,  5.68s/it]--------------------------------------------- Result 6 ---------------------------------------------
# <pad> Hier ist, was er zu Beginn schrieb</s> --> [38:5:240m[SKIPPED]
#
# Here &apos;s what he wrote in starting that out .
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 4 / 1 / 6:   7% 7/100 [00:39<08:41,  5.61s/it]--------------------------------------------- Result 7 ---------------------------------------------
# <pad> Er sagte: „Hier ist es.</s> --> [FAILED]
#
# He said , &quot; &quot; Here it is . I &apos;m dead , and this is my last post to my blog .
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 5 / 1 / 7:   8% 8/100 [01:09<13:13,  8.63s/it]--------------------------------------------- Result 8 ---------------------------------------------
# <pad> Ich habe vorab gebeten, dass mein Körper, sobald er endlich aus --> [FAILED]
#
# In advance , I asked that once my body finally shut down from the punishments of my cancer , then my family and friends publish this prepared message I wrote — the first part of the process of turning this from an active website to an archive . &quot; &quot; Now , while as a journalist , Miller &apos;s archive may have been better written and more carefully curated than most , the fact of the matter is that all of us today are creating an archive that &apos;s something completely different than anything that &apos;s been created by any previous generation .
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 6 / 1 / 8:   9% 9/100 [01:09<11:40,  7.70s/it]--------------------------------------------- Result 9 ---------------------------------------------
# <pad> Betrachten Sie einige Statistiken für einen Moment .</s> --> [38:5:240m[SKIPPED]
#
# Consider a few stats for a moment .
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 6 / 2 / 9:  10% 10/100 [01:09<10:25,  6.95s/it]--------------------------------------------- Result 10 ---------------------------------------------
# <pad> Momentan werden 48 Stunden Video auf YouTube hochgeladen.</s> --> [38:5:240m[SKIPPED]
#
# Right now there are 48 hours of video being uploaded to YouTube every single minute .
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 6 / 3 / 10:  11% 11/100 [01:10<09:32,  6.43s/it]--------------------------------------------- Result 11 ---------------------------------------------
# <pad> Jeden Tag werden 200 Millionen Tweets veröffentlicht.</s> --> <pad> Ai sind 200 Millionen Tweets täglich .</s><pad><pad><pad><pad><pad>
#
# There are 200 million Tweets being posted every day .
#
# Ai are 200 million Tweets being posted every day .
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 6 / 3 / 11:  12% 12/100 [01:11<08:40,  5.92s/it]--------------------------------------------- Result 12 ---------------------------------------------
# <pad> Und der durchschnittliche Facebook-Benutzer erstellt monatlich 90 Artikel.</s> --> [38:5:240m[SKIPPED]
#
# And the average Facebook user is creating 90 pieces of content each month .
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 6 / 4 / 12:  13% 13/100 [01:20<08:57,  6.17s/it]--------------------------------------------- Result 13 ---------------------------------------------
# <pad> Wenn man also an seine Eltern oder Großeltern denkt, dann ist das bestenfalls --> [FAILED]
#
# So when you think about your parents or your grandparents , at best they may have created some photos or home videos , or a diary that lives in a box somewhere .
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 7 / 4 / 13:  14% 14/100 [01:26<08:53,  6.20s/it]--------------------------------------------- Result 14 ---------------------------------------------
# <pad> Aber heute schaffen wir alle diese unglaublich reiche</s> --> [FAILED]
#
# But today we &apos;re all creating this incredibly rich digital archive that &apos;s going to live in the cloud indefinitely , years after we &apos;re gone .
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 8 / 4 / 14:  15% 15/100 [01:27<08:13,  5.81s/it]--------------------------------------------- Result 15 ---------------------------------------------
# <pad> Und ich denke, dass das einige <unk>nderungen schaffen wird.</s> --> [38:5:240m[SKIPPED]
#
# And I think that &apos;s going to create some incredibly intriguing opportunities for technologists .
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 8 / 5 / 15:  16% 16/100 [01:36<08:27,  6.04s/it]--------------------------------------------- Result 16 ---------------------------------------------
# <pad> Um es klar zu sagen , ich bin ein</s> --> [FAILED]
#
# Now to be clear , I &apos;m a journalist and not a technologist , so what I &apos;d like to do briefly is paint a picture of what the present and the future are going to look like .
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 9 / 5 / 16:  17% 17/100 [01:44<08:31,  6.17s/it]--------------------------------------------- Result 17 ---------------------------------------------
# <pad> Jetzt sehen wir bereits einige Dienstleistungen, die</s> --> [FAILED]
#
# Now we &apos;re already seeing some services that are designed to let us decide what happens to our online profile and our social media accounts after we die .
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 10 / 5 / 17:  18% 18/100 [01:53<08:36,  6.29s/it]--------------------------------------------- Result 18 ---------------------------------------------
# <pad> Einer dieser hat mich tatsächlich gefunden, als er - recht treffen --> [FAILED]
#
# One of them actually , fittingly enough , found me when I checked into a deli at a restaurant in New York on foursquare .
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 11 / 5 / 18:  19% 19/100 [01:53<08:04,  5.98s/it]--------------------------------------------- Result 19 ---------------------------------------------
# <pad> ( Aufzeichnung ) Adam Ostrow : Hallo .</s> --> [38:5:240m[SKIPPED]
#
# ( Recording ) Adam Ostrow : Hello .
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 11 / 6 / 19:  20% 20/100 [01:53<07:34,  5.69s/it]--------------------------------------------- Result 20 ---------------------------------------------
# <pad> Tod: Adam ?</s> --> [38:5:240m[SKIPPED]
#
# Death : Adam ?
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 11 / 7 / 20:  21% 21/100 [01:53<07:08,  5.42s/it]--------------------------------------------- Result 21 ---------------------------------------------
# <pad> AO : Ja .</s> --> [38:5:240m[SKIPPED]
#
# AO : Yeah .
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 11 / 8 / 21:  22% 22/100 [01:55<06:49,  5.24s/it]--------------------------------------------- Result 22 ---------------------------------------------
# <pad> Tod : Der Tod kann dich überall , jederzeit , auch er --> <pad> Tod : Der Tod kann Sie im Ausland fangen , jederzeit , auch
#
# Death : Death can catch you anywhere , anytime , even at the Organic .
#
# Death : Death can catch you abroad , anytime , even at the Organic .
#
#
# [Succeeded / Failed / Skipped / Total] 3 / 11 / 8 / 22:  23% 23/100 [01:55<06:26,  5.02s/it]--------------------------------------------- Result 23 ---------------------------------------------
# <pad> AO : Wer ist das ?</s> --> [38:5:240m[SKIPPED]
#
# AO : Who is this ?
#
#
# [Succeeded / Failed / Skipped / Total] 3 / 11 / 9 / 23:  24% 24/100 [01:57<06:10,  4.88s/it]--------------------------------------------- Result 24 ---------------------------------------------
# <pad> Tod : Gehen Sie zu ifidie.net bevor es  --> <pad> Mörder : Gehen Sie zu ifidie.net bevor</s><pad><pad>
#
# Death : Go to ifidie.net before it &apos;s too late .
#
# Assassinate : Go to ifidie.net before it &apos;s too late .
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 11 / 9 / 24:  25% 25/100 [01:57<05:52,  4.70s/it]--------------------------------------------- Result 25 ---------------------------------------------
# <pad> ( Heiterkeit ) Adam Ostrow : Kindes schleich --> [38:5:240m[SKIPPED]
#
# ( Laughter ) Adam Ostrow : Kind of creepy , right ?
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 11 / 10 / 25:  26% 26/100 [02:05<05:57,  4.83s/it]--------------------------------------------- Result 26 ---------------------------------------------
# <pad> Was dieser Dienst also tut, ist ganz einfach, Ihnen zu ermöglichen</s> --> [FAILED]
#
# So what that service does , quite simply , is let you create a message or a video that can be posted to Facebook after you die .
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 12 / 10 / 26:  27% 27/100 [02:05<05:40,  4.66s/it]--------------------------------------------- Result 27 ---------------------------------------------
# <pad> Ein weiterer Service ist jetzt namens 1,000 Memories .</s> --> [38:5:240m[SKIPPED]
#
# Another service right now is called 1,000 Memories .
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 12 / 11 / 27:  28% 28/100 [02:16<05:49,  4.86s/it]--------------------------------------------- Result 28 ---------------------------------------------
# <pad> Und was Sie damit tun können, ist eine Online-Hommage an Ihre Lieben zu  --> [FAILED]
#
# And what this lets you do is create an online tribute to your loved ones , complete with photos and videos and stories that they can post after you die .
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 13 / 11 / 28:  29% 29/100 [02:16<05:33,  4.70s/it]--------------------------------------------- Result 29 ---------------------------------------------
# <pad> Aber was ich denke, kommt als nächstes ist viel interessanter .</s> --> [38:5:240m[SKIPPED]
#
# But what I think comes next is far more interesting .
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 13 / 12 / 29:  30% 30/100 [02:25<05:39,  4.85s/it]--------------------------------------------- Result 30 ---------------------------------------------
# <pad> Nun sind viele von Ihnen wahrscheinlich mit Deb Roy vertraut, der</s> --> [FAILED]
#
# Now a lot of you are probably familiar with Deb Roy who , back in March , demonstrated how he was able to analyze more than 90,000 hours of home video .
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 14 / 12 / 30:  31% 31/100 [02:47<06:11,  5.39s/it]--------------------------------------------- Result 31 ---------------------------------------------
# <pad> Ich denke, als Maschinen die Fähigkeit, menschliche Sprache zu verstehen und</s> --> [FAILED]
#
# I think as machines &apos; ability to understand human language and process vast amounts of data continues to improve , it &apos;s going to become possible to analyze an entire life &apos;s worth of content — the Tweets , the photos , the videos , the blog posts — that we &apos;re producing in such massive numbers .
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 15 / 12 / 31:  32% 32/100 [03:06<06:35,  5.82s/it]--------------------------------------------- Result 32 ---------------------------------------------
# <pad> Und ich denke, dass es, so wie das passiert ,</s> --> [FAILED]
#
# And I think as that happens , it &apos;s going to become possible for our digital personas to continue to interact in the real world long after we &apos;re gone thanks to the vastness of the amount of content we &apos;re creating and technology &apos;s ability to make sense of it all .
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 16 / 12 / 32:  33% 33/100 [03:06<06:18,  5.65s/it]--------------------------------------------- Result 33 ---------------------------------------------
# <pad> Jetzt beginnen wir schon, hier einige Experimente zu sehen.</s> --> [38:5:240m[SKIPPED]
#
# Now we &apos;re already starting to see some experiments here .
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 16 / 13 / 33:  34% 34/100 [03:21<06:30,  5.91s/it]--------------------------------------------- Result 34 ---------------------------------------------
# <pad> Ein Dienst mit dem Namen My Next Tweet analysiert Ihren gesamten Twitter-Stream  --> [FAILED]
#
# One service called My Next Tweet analyzes your entire Twitter stream , everything you &apos;ve posted onto Twitter , to make some predictions as to what you might say next .
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 17 / 13 / 34:  35% 35/100 [03:22<06:16,  5.79s/it]--------------------------------------------- Result 35 ---------------------------------------------
# <pad> Nun, gerade jetzt , wie Sie sehen können , die Ergebnisse können</s> --> <pad> Nun, wie Sie sehen können, sind die Errungenschaften</s><pad><pad><pad><pad>
#
# Well right now , as you can see , the results can be somewhat comical .
#
# Well right now , as you can see , the accomplishments can be somewhat comical .
#
#
# [Succeeded / Failed / Skipped / Total] 5 / 17 / 13 / 35:  36% 36/100 [03:24<06:03,  5.69s/it]--------------------------------------------- Result 36 ---------------------------------------------
# <pad> Sie können sich vorstellen, wie etwas so etwas aussehen könnte fünf , 10</s> --> <pad> Ya can believe what something like this might look like five, 10</s><pad><pad><pad><pad><pad>
#
# You can imagine what something like this might look like five , 10 or 20 years from now as our technical capabilities improve .
#
# Ya can believe what something like this might look like five , 10 or 20 years from now as our technical capabilities improve .
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 17 / 13 / 36:  37% 37/100 [03:30<05:58,  5.70s/it]--------------------------------------------- Result 37 ---------------------------------------------
# <pad> Einen Schritt weiter : MIT</s> --> [FAILED]
#
# Taking it a step further , MIT &apos;s media lab is working on robots that can interact more like humans .
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 18 / 13 / 37:  38% 38/100 [03:42<06:03,  5.86s/it]--------------------------------------------- Result 38 ---------------------------------------------
# <pad> Aber was, wenn diese Roboter in der Lage waren, interagieren basierend --> [FAILED]
#
# But what if those robots were able to interact based on the unique characteristics of a specific person based on the hundreds of thousands of pieces of content that person produces in their lifetime ?
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 19 / 13 / 38:  39% 39/100 [03:59<06:14,  6.14s/it]--------------------------------------------- Result 39 ---------------------------------------------
# <pad> Schließlich denken Sie an diese berühmte Szene aus der Nacht der Wahlen 2008 zurück</s> --> [FAILED]
#
# Finally , think back to this famous scene from election night 2008 back in the United States , where CNN beamed a live hologram of hip hop artist will.i.am into their studio for an interview with Anderson Cooper .
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 20 / 13 / 39:  40% 40/100 [04:09<06:14,  6.25s/it]--------------------------------------------- Result 40 ---------------------------------------------
# <pad> Was wäre, wenn wir dieselbe Art von Technologie nutzen könnten?</s> --> [FAILED]
#
# What if we were able to use that same type of technology to beam a representation of our loved ones into our living rooms — interacting in a very lifelike way based on all the content they created while they were alive ?
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 21 / 13 / 40:  41% 41/100 [04:18<06:11,  6.30s/it]--------------------------------------------- Result 41 ---------------------------------------------
# <pad> Ich denke, dass dies völlig möglich wird, wenn</s> --> [FAILED]
#
# I think that &apos;s going to become completely possible as the amount of data we &apos;re producing and technology &apos;s ability to understand it both expand exponentially .
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 22 / 13 / 41:  42% 42/100 [04:27<06:09,  6.38s/it]--------------------------------------------- Result 42 ---------------------------------------------
# <pad> Abschließend möchte ich sagen, was wir alle denken müssen.</s> --> [FAILED]
#
# Now in closing , I think what we all need to be thinking about is if we want that to become our reality — and if so , what it means for a definition of life and everything that comes after it .
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 23 / 13 / 42:  43% 43/100 [04:27<05:55,  6.23s/it]--------------------------------------------- Result 43 ---------------------------------------------
# <pad> Vielen Dank .</s> --> [38:5:240m[SKIPPED]
#
# Thank you very much .
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 23 / 14 / 43:  44% 44/100 [04:28<05:41,  6.09s/it]--------------------------------------------- Result 44 ---------------------------------------------
# <pad> ( Beifall )</s> --> [38:5:240m[SKIPPED]
#
# ( Applause )
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 23 / 15 / 44:  45% 45/100 [04:28<05:28,  5.96s/it]--------------------------------------------- Result 45 ---------------------------------------------
# <pad> ( Gitarre ) ( Gesang ) Achterbahn .</s> --> [38:5:240m[SKIPPED]
#
# ( Guitar ) ( Singing ) Rollercoaster , carousel .
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 23 / 16 / 45:  46% 46/100 [04:33<05:21,  5.95s/it]--------------------------------------------- Result 46 ---------------------------------------------
# <pad> Sie können den Klingel holen, Sie können die Glocke klingen --> [FAILED]
#
# You can grab the ring , you can ring that bell , when the ride is over , you can never tell .
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 24 / 16 / 46:  47% 47/100 [04:34<05:09,  5.83s/it]--------------------------------------------- Result 47 ---------------------------------------------
# <pad> Die Leute sagen Ihnen, dass das eine — Ihr Leben komplett machen wird —</s> --> [38:5:240m[SKIPPED]
#
# People tell you this one thing — will make your life complete .
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 24 / 17 / 47:  48% 48/100 [04:35<04:58,  5.74s/it]--------------------------------------------- Result 48 ---------------------------------------------
# <pad> Also du , du gibst alles, was du hast, und du sch --> <pad> Dementsprechend , geben Sie ihm alles, was Sie bekommen, und Sie winden</s>
#
# So you , you give it everything you got and you wind up on the street .
#
# Accordingly you , you give it everything you got and you wind up on the street .
#
#
# [Succeeded / Failed / Skipped / Total] 7 / 24 / 17 / 48:  49% 49/100 [04:46<04:58,  5.85s/it]--------------------------------------------- Result 49 ---------------------------------------------
# <pad> Dann wachst du eines Tages auf und sie sagen dir:</s> --> [FAILED]
#
# Then one day you wake up , and they tell you &quot; &quot; you &apos;re a queen , &quot; &quot; but then you find that someone else is pulling on the strings .
#
#
# [Succeeded / Failed / Skipped / Total] 7 / 25 / 17 / 49:  50% 50/100 [04:46<04:46,  5.74s/it]--------------------------------------------- Result 50 ---------------------------------------------
# <pad> Rollercoaster , Karussell .</s> --> [38:5:240m[SKIPPED]
#
# Rollercoaster , carousel .
#
#
# [Succeeded / Failed / Skipped / Total] 7 / 25 / 18 / 50:  51% 51/100 [04:49<04:37,  5.67s/it]--------------------------------------------- Result 51 ---------------------------------------------
# <pad> Wo die Höhen der Himmel sind, aber die Tiefen,</s> --> <pad> Wo die Höhen Himmel sind, aber die Tiefen</s><pad><pad><pad><pad><pad>
#
# Where the highs are heaven , but the lows , oh , they can be hell .
#
# Where the altitudes are heaven , but the lows , oh , they can be hell .
#
#
# [Succeeded / Failed / Skipped / Total] 8 / 25 / 18 / 51:  52% 52/100 [04:51<04:28,  5.60s/it]--------------------------------------------- Result 52 ---------------------------------------------
# <pad> Wo die Höhen Himmel sind, aber die Tiefen, o</s> --> <pad> Wo die Höhen der Himmel sind, aber die Tiefen, oderch</s><pad><pad>
#
# Where the highs are heaven but the lows , oh , they can be hell .
#
# Where the highs are heaven but the lows , ouch , they can be hell .
#
#
# [Succeeded / Failed / Skipped / Total] 9 / 25 / 18 / 52:  53% 53/100 [04:57<04:24,  5.62s/it]--------------------------------------------- Result 53 ---------------------------------------------
# <pad> Nun , vielleicht bin ich einfach cy</s> --> [FAILED]
#
# Well , maybe I &apos;m just cynical , and all these words are lies , but experience keeps telling me that the cautious one is wise .
#
#
# [Succeeded / Failed / Skipped / Total] 9 / 26 / 18 / 53:  54% 54/100 [05:05<04:19,  5.65s/it]--------------------------------------------- Result 54 ---------------------------------------------
# <pad> Aber Vorsicht macht Sie zögern , und zöger --> [FAILED]
#
# But caution makes you hesitate , and hesitate you &apos;re lost , so take your opportunities and never count the cost .
#
#
# [Succeeded / Failed / Skipped / Total] 9 / 27 / 18 / 54:  55% 55/100 [05:05<04:09,  5.55s/it]--------------------------------------------- Result 55 ---------------------------------------------
# <pad> Rollercoaster , Karussell .</s> --> [38:5:240m[SKIPPED]
#
# Rollercoaster , carousel .
#
#
# [Succeeded / Failed / Skipped / Total] 9 / 27 / 19 / 55:  56% 56/100 [05:06<04:00,  5.47s/it]--------------------------------------------- Result 56 ---------------------------------------------
# <pad> Karussell , Karussell , Karussell</s> --> <pad> Carousel , Harrods , carous</s><pad><pad><pad><pad><pad>
#
# Carousel , carousel , carousel , carousel .
#
# Carousel , harrods , carousel , carousel .
#
#
# [Succeeded / Failed / Skipped / Total] 10 / 27 / 19 / 56:  57% 57/100 [05:06<03:51,  5.38s/it]--------------------------------------------- Result 57 ---------------------------------------------
# <pad> ( Beifall) Michael Pemberton . (</s> --> [38:5:240m[SKIPPED]
#
# ( Applause ) Michael Pemberton . ( Applause )
#
#
# [Succeeded / Failed / Skipped / Total] 10 / 27 / 20 / 57:  58% 58/100 [05:07<03:42,  5.29s/it]--------------------------------------------- Result 58 ---------------------------------------------
# <pad> Vielen Dank .</s> --> [38:5:240m[SKIPPED]
#
# Thank you so much .
#
#
# [Succeeded / Failed / Skipped / Total] 10 / 27 / 21 / 58:  59% 59/100 [05:07<03:33,  5.21s/it]--------------------------------------------- Result 59 ---------------------------------------------
# <pad> Vielen Dank.</s> --> [38:5:240m[SKIPPED]
#
# Thank you .
#
#
# [Succeeded / Failed / Skipped / Total] 10 / 27 / 22 / 59:  59% 59/100 [05:07<03:33,  5.21s/it]
#
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 10     |
# | Number of failed attacks:     | 27     |
# | Number of skipped attacks:    | 22     |
# | Original accuracy:            | 62.71% |
# | Accuracy under attack:        | 45.76% |
# | Attack success rate:          | 27.03% |
# | Average perturbed word %:     | 9.87%  |
# | Average num. words per input: | 19.46  |
# | Avg num queries:              | 590.43 |
# +-------------------------------+--------+

# %% [markdown]
# ## Attack a LLaMa model
#
# ### Install dependencies

# %%
# %cd textattack-example/
# !poetry add transformers torch
# !poetry add numpy==1.25.2
# %cd ..
# Out:
# /content/textattack-example
# Skipping virtualenv creation, as specified in config file.
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   - transformers
#   - torch
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Nothing to add.
# Found existing installation: numpy 1.25.2
# Uninstalling numpy-1.25.2:
#   Successfully uninstalled numpy-1.25.2
# Skipping virtualenv creation, as specified in config file.
#
# Updating dependencies
# Resolving dependencies... (0.8s)
#
# Package operations: 1 install, 0 updates, 0 removals
#
#   - Installing numpy (1.25.2): Pending...
#   - Installing numpy (1.25.2): Installing...
#   - Installing numpy (1.25.2)
# /content

# %% [markdown]
# ### Load LLaMa model
#
# We load the model using the transformers library

# %%
# !pip show numpy

from transformers import AutoTokenizer, AutoModelForCausalLM

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("huggyllama/llama-7b")
model = AutoModelForCausalLM.from_pretrained("huggyllama/llama-7b")
# Out:
# Name: numpy
# Version: 1.25.2
# Summary: Fundamental package for array computing in Python
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.11/dist-packages
# Requires:
# Required-by: accelerate, albucore, albumentations, ale-py, arviz, astropy, autograd, bert-score, bigframes, blis, blosc2, bokeh, Bottleneck, bqplot, chex, clarabel, cmdstanpy, contourpy, cudf-cu12, cufflinks, cuml-cu12, cupy-cuda12x, cuvs-cu12, cvxpy, cyipopt, dask-cuda, dask-cudf-cu12, datascience, datasets, db-dtypes, diffusers, dm-tree, dopamine_rl, flax, folium, geemap, geopandas, gym, gymnasium, h5py, hdbscan, highspy, holoviews, hyperopt, imageio, imbalanced-learn, jax, jaxlib, keras, keras-hub, lemminflect, librosa, lightgbm, matplotlib, matplotlib-venn, missingno, mizani, ml-dtypes, mlxtend, moviepy, music21, nibabel, numba, numexpr, nx-cugraph-cu12, opencv-contrib-python, opencv-python, opencv-python-headless, optax, orbax-checkpoint, osqp, pandas, pandas-gbq, pandas-stubs, patsy, peft, plotnine, prophet, pycocotools, pyerfa, pylibcugraph-cu12, pylibraft-cu12, pymc, pyogrio, pytensor, python-louvain, pytorch_revgrad, qdldl, rmm-cu12, scikit-image, scikit-learn, scipy, scs, seaborn, shap, shapely, sklearn-pandas, soundfile, soxr, spacy, spanner-graph-notebook, stanio, statsmodels, tables, tensorboard, tensorflow, tensorflow-datasets, tensorflow-hub, tensorflow-probability, tensorstore, textattack, thinc, tifffile, torchvision, transformers, treelite, treescope, ucx-py-cu12, ucxx-cu12, umap-learn, wordcloud, xarray, xarray-einstats, xgboost, yellowbrick, yfinance
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1967         try:
# -> 1968             return importlib.import_module("." + module_name, self.__name__)
#    1969         except Exception as e:
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in <module>
#      29
# ---> 30 from transformers.generation.candidate_generator import AssistantVocabTranslatorCache
#      31
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/candidate_generator.py in <module>
#      26 if is_sklearn_available():
# ---> 27     from sklearn.metrics import roc_curve
#      28
#
# /usr/local/lib/python3.11/dist-packages/sklearn/__init__.py in <module>
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in <module>
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/__init__.py in <module>
#      14 from ._bunch import Bunch
# ---> 15 from ._chunking import gen_batches, gen_even_slices
#      16 from ._estimator_html_repr import estimator_html_repr
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_chunking.py in <module>
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      12
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in <module>
#      13 import numpy as np
# ---> 14 from scipy.sparse import csr_matrix, issparse
#      15
#
# /usr/local/lib/python3.11/dist-packages/scipy/sparse/__init__.py in <module>
#     299
# --> 300 from ._base import *
#     301 from ._csr import *
#
# /usr/local/lib/python3.11/dist-packages/scipy/sparse/_base.py in <module>
#       4
# ----> 5 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       6                        get_sum_dtype, isdense, isscalarlike,
#
# /usr/local/lib/python3.11/dist-packages/scipy/sparse/_sputils.py in <module>
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      11
#
# /usr/local/lib/python3.11/dist-packages/scipy/_lib/_util.py in <module>
#      12 import numpy as np
# ---> 13 from scipy._lib._array_api import array_namespace, is_numpy, xp_size
#      14 from scipy._lib._docscrape import FunctionDoc, Parameter
#
# /usr/local/lib/python3.11/dist-packages/scipy/_lib/_array_api.py in <module>
#      17 from scipy._lib import array_api_compat
# ---> 18 from scipy._lib.array_api_compat import (
#      19     is_array_api_obj,
#
# /usr/local/lib/python3.11/dist-packages/scipy/_lib/array_api_compat/numpy/__init__.py in <module>
# ----> 1 from numpy import * # noqa: F403
#       2
#       3 # from numpy import * doesn't overwrite these builtin names
#
# /usr/local/lib/python3.11/dist-packages/numpy/__init__.py in __getattr__(attr)
#     366                    "numpy issues for similar problems.")
# --> 367             raise RuntimeError(msg.format(__file__)) from None
#     368
#
# ModuleNotFoundError: No module named 'numpy.char'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1967         try:
# -> 1968             return importlib.import_module("." + module_name, self.__name__)
#    1969         except Exception as e:
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py in <module>
#      37 from ..encoder_decoder import EncoderDecoderConfig
# ---> 38 from .auto_factory import _LazyAutoMapping
#      39 from .configuration_auto import (
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in <module>
#      39 if is_torch_available():
# ---> 40     from ...generation import GenerationMixin
#      41
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1955         elif name in self._class_to_module.keys():
# -> 1956             module = self._get_module(self._class_to_module[name])
#    1957             value = getattr(module, name)
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1969         except Exception as e:
# -> 1970             raise RuntimeError(
#    1971                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#
# RuntimeError: Failed to import transformers.generation.utils because of the following error (look up to see its traceback):
# No module named 'numpy.char'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-9f2e599515df> in <cell line: 0>()
#       1 get_ipython().system('pip show numpy')
#       2
# ----> 3 from transformers import AutoTokenizer, AutoModelForCausalLM
#       4
#       5 # Load tokenizer and model
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1955         elif name in self._class_to_module.keys():
#    1956             module = self._get_module(self._class_to_module[name])
# -> 1957             value = getattr(module, name)
#    1958         elif name in self._modules:
#    1959             value = self._get_module(name)
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1954             value = Placeholder
#    1955         elif name in self._class_to_module.keys():
# -> 1956             module = self._get_module(self._class_to_module[name])
#    1957             value = getattr(module, name)
#    1958         elif name in self._modules:
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1968             return importlib.import_module("." + module_name, self.__name__)
#    1969         except Exception as e:
# -> 1970             raise RuntimeError(
#    1971                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1972                 f" traceback):\n{e}"
#
# RuntimeError: Failed to import transformers.models.auto.tokenization_auto because of the following error (look up to see its traceback):
# Failed to import transformers.generation.utils because of the following error (look up to see its traceback):
# No module named 'numpy.char'
